# %% [markdown]
# # Plant core genes lost with parasitism
#
# ## Method
#
# * Orthologous Groups were inferred using [SonicParanoid2](https://genomebiology.biomedcentral.com/articles/10.1186/s13059-024-03298-4) (graph-based only)
#
# ## Dataset
#
# * 5 hemi-parasitic plants
# * 5 holo-parasitic plants
# * 18 non-parasitic plant (One per order of the Pentapetalae)

# %%
from IPython.display import Image

fig = Image(filename=('28_parasiticplants_tree.png'), width=800)
fig
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from IPython.display import Image
# ----> 3 fig = Image(filename=('28_parasiticplants_tree.png'), width=800)
#       4 fig
#
# File ~/miniforge3/envs/DA/lib/python3.13/site-packages/IPython/core/display.py:1025, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#    1023 self.unconfined = unconfined
#    1024 self.alt = alt
# -> 1025 super(Image, self).__init__(data=data, url=url, filename=filename,
#    1026         metadata=metadata)
#    1028 if self.width is None and self.metadata.get('width', {}):
#    1029     self.width = metadata['width']
#
# File ~/miniforge3/envs/DA/lib/python3.13/site-packages/IPython/core/display.py:343, in DisplayObject.__init__(self, data, url, filename, metadata)
#     340 elif self.metadata is None:
#     341     self.metadata = {}
# --> 343 self.reload()
#     344 self._check_data()
#
# File ~/miniforge3/envs/DA/lib/python3.13/site-packages/IPython/core/display.py:1060, in Image.reload(self)
#    1058 """Reload the raw data from file or URL."""
#    1059 if self.embed:
# -> 1060     super(Image,self).reload()
#    1061     if self.retina:
#    1062         self._retina_shape()
#
# File ~/miniforge3/envs/DA/lib/python3.13/site-packages/IPython/core/display.py:369, in DisplayObject.reload(self)
#     367 if self.filename is not None:
#     368     encoding = None if "b" in self._read_flags else "utf-8"
# --> 369     with open(self.filename, self._read_flags, encoding=encoding) as f:
#     370         self.data = f.read()
#     371 elif self.url is not None:
#     372     # Deferred import
#
# FileNotFoundError: [Errno 2] No such file or directory: '28_parasiticplants_tree.png'

# %% [markdown]
# **Figure:** Phylogenetic tree of 10 parasitic and 18 non-parasitic plants. Pruned from [Zuntini et al. 2024, Nature](https://www.nature.com/articles/s41586-024-07324-0)

# %% [markdown]
# # Phylogenetic profile of lost core genes
#
# Orthologous groups (OGs) of (non-parasitic) plant core genes are shown in the rows. The 28 plant taxa considered in this analysis are shown in the columns.
#
# Non-parasitic plants are shown in blue, hemi-parasitic plants are shown in grey, and holo-parasitic plants are shown in yellow.
#
# The hoverover information displays the protein_ids assigend to the OG in the corresponding plant species. Additionally, the functional annotation of the ortholog in _A. thaliana_ is shown.
#
# ### Parameters
#
# * **Core factor**: Ratio of non-parasitic plants in which a gene must be found to be considered a "core gene"
# * **Loss factor**: Ratio of parasitic plants in which a gene must be absent to be considered "lost with parasitism"
# * **Annotation**: If "first" show the annotation of the first co-ortholog in _A. thaliana_, if "all" show the annotation of all co-orthologs

# %%
# import pandas as pd
# import json
# import plotly.graph_objects as go
# import ipywidgets as widgets
# from IPython.display import display

# from loading import generate_widgets, get_parasets
# from process_core import find_genes_lost_for_parasitism
# from prepare_plotting import prepare_for_heatmap

# # --- widgets ---
# core_factor, loss_factor, propagate_annotation = generate_widgets()
# display(core_factor, loss_factor, propagate_annotation)

# # --- input paths ---
# para_nonpara_overview = f'data/28taxa_overview.tsv'
# og_path = f'data/28taxa_orthogroups.tsv'
# ath_anno_path = 'data/ath_protid2annotation.json'

# # --- load data (once) ---
# taxadf = pd.read_csv(para_nonpara_overview, sep='\t')
# nonparasitic, parasitic, holoparasites, hemiparasites = get_parasets(taxadf)
# column_names = [f'{name}.fa' for name in hemiparasites + holoparasites]

# orthodf = pd.read_csv(og_path, sep='\t')

# with open(ath_anno_path) as fh:
#     ath_protid2annotation = json.load(fh)

# # --- output area for plot ---
# out = widgets.Output()
# display(out)

# # --- function to update the plot ---
# def extract_athaliana_protids(df):
#     print('# NCBI RefSeq Protein IDs of lost core genes in A. thaliana for enrichment analysis:\n')
#     for value in df['Athaliana.fa'].values:
#         if ',' in value:
#             for coortho in value.split(','):
#                 print(coortho)
#         elif value == '*':
#             continue
#         else:
#             print(value)

# def update_plot(change=None):
#     with out:
#         out.clear_output(wait=True)

#         # process data with current widget values
#         loss_overview, lost_orthodf = find_genes_lost_for_parasitism(
#             orthodf,
#             nonparasitic,
#             parasitic,
#             column_names,
#             core_factor=core_factor.value,
#             loss_factor=loss_factor.value
#         )

#         heatmap_df, label_df, anno_df, xlabels, ylabels = prepare_for_heatmap(
#             lost_orthodf,
#             taxadf,
#             ath_protid2annotation,
#             propagate_annotation.value,
#             nonparasitic,
#             hemiparasites,
#             holoparasites
#         )

#         # build heatmap
#         fig = go.Figure(data=go.Heatmap(
#             z=heatmap_df,
#             x=xlabels,
#             y=ylabels,
#             text=label_df,
#             customdata=anno_df,
#             hoverinfo='x+text',
#             hoverongaps=False,
#             showscale=False,
#             type='heatmap',
#             colorscale='Cividis',
#             hovertemplate="<b>%{x}</b><br>%{customdata}<br>%{text}<br><br><extra></extra>",
#         ))

#         # layout
#         row_height = 20
#         height = max(400, row_height * heatmap_df.index.size)
#         fig.update_layout(
#             width=800,
#             height=height
#         )

#         n_rows, n_cols = heatmap_df.shape
#         shapes = []
#         for i in range(1, n_cols):
#             shapes.append(dict(
#                 type="line",
#                 x0=i-0.5, x1=i-0.5,
#                 y0=-0.5, y1=n_rows-0.5,
#                 line=dict(color="white", width=1)
#             ))
#         for j in range(1, n_rows):
#             shapes.append(dict(
#                 type="line",
#                 x0=-0.5, x1=n_cols-0.5,
#                 y0=j-0.5, y1=j-0.5,
#                 line=dict(color="white", width=1)
#             ))

#         fig.update_layout(
#             shapes=shapes,
#             xaxis=dict(showgrid=False),
#             yaxis=dict(showgrid=False, autorange="reversed")
#         )
#         display(fig)


# # --- connect widgets to update ---
# core_factor.observe(update_plot, names="value")
# loss_factor.observe(update_plot, names="value")
# propagate_annotation.observe(update_plot, names="value")

# # --- initial draw ---
# update_plot()

# %%
import pandas as pd
import json
import plotly.express as px
import plotly.graph_objects as go

from loading import generate_widgets, get_parasets
from process_core import find_genes_lost_for_parasitism
from prepare_plotting import prepare_for_heatmap

# %%
# --- imports ---
import pandas as pd
import json
import plotly.graph_objects as go
import ipywidgets as widgets
from IPython.display import display
import traceback

from loading import generate_widgets, get_parasets
from process_core import find_genes_lost_for_parasitism
from prepare_plotting import prepare_for_heatmap

# --- widgets ---
core_factor, loss_factor, propagate_annotation = generate_widgets()
controls = widgets.VBox([widgets.HBox([core_factor, loss_factor]), propagate_annotation])
display(controls)

# --- small status / log area ---
status = widgets.HTML(value="")
display(status)

# --- input paths ---
para_nonpara_overview = 'data/28taxa_overview.tsv'
og_path = 'data/28taxa_orthogroups.tsv'
ath_anno_path = 'data/ath_protid2annotation.json'

# --- load static data once ---
taxadf = pd.read_csv(para_nonpara_overview, sep='\t')
nonparasitic, parasitic, holoparasites, hemiparasites = get_parasets(taxadf)
column_names = [f'{name}.fa' for name in hemiparasites + holoparasites]

orthodf = pd.read_csv(og_path, sep='\t')
with open(ath_anno_path) as fh:
    ath_protid2annotation = json.load(fh)

# --- helper to convert dataframes/series into nested lists ready for plotly ---
def to_nested_list(df_like):
    # Accept pandas DataFrame or Series or numpy arrays
    try:
        return df_like.values.tolist()
    except Exception:
        return df_like.tolist()

# --- initial processing (synchronous) ---
loss_overview, lost_orthodf = find_genes_lost_for_parasitism(
    orthodf, nonparasitic, parasitic, column_names,
    core_factor=core_factor.value, loss_factor=loss_factor.value
)
heatmap_df, label_df, anno_df, xlabels, ylabels = prepare_for_heatmap(
    lost_orthodf, taxadf, ath_protid2annotation,
    propagate_annotation.value, nonparasitic, hemiparasites, holoparasites
)

# --- prepare arrays for Plotly ---
# z = to_nested_list(heatmap_df)
# text = to_nested_list(label_df)
# customdata = to_nested_list(anno_df)
n_rows, n_cols = heatmap_df.shape


# --- shapes (grid lines) ---
row_height = 20
height = max(400, row_height * n_rows)
shapes = []
for i in range(1, n_cols):
    shapes.append(dict(type="line", x0=i-0.5, x1=i-0.5, y0=-0.5, y1=n_rows-0.5, line=dict(color="white", width=1)))
for j in range(1, n_rows):
    shapes.append(dict(type="line", x0=-0.5, x1=n_cols-0.5, y0=j-0.5, y1=j-0.5, line=dict(color="white", width=1)))

# --- create a FigureWidget (display once) ---
fig_w = go.FigureWidget(
    data=[
        go.Heatmap(
            z=heatmap_df,
            x=xlabels,
            y=ylabels,
            text=label_df,
            customdata=anno_df,
            hoverinfo='x+text',
            hoverongaps=False,
            showscale=False,
            colorscale='Cividis',
            hovertemplate="<b>%{x}</b><br>%{customdata}<br>%{text}<br><br><extra></extra>",
        )
    ]
)
fig_w.update_layout(width=800, height=height, shapes=shapes,
                    xaxis=dict(showgrid=False), yaxis=dict(showgrid=False, autorange="reversed"))

display(fig_w)  # displayed once; subsequent updates mutate this widget in-place

# --- update callback (in-place updates using batch_update) ---
def update_plot(change=None):
    """Compute new heatmap and update the FigureWidget in-place."""
    try:
        status.value = "<i>processing…</i>"
        # compute (may take some time)
        loss_overview, lost_orthodf = find_genes_lost_for_parasitism(
            orthodf, nonparasitic, parasitic, column_names,
            core_factor=core_factor.value, loss_factor=loss_factor.value
        )
        heatmap_df, label_df, anno_df, xlabels, ylabels = prepare_for_heatmap(
            lost_orthodf, taxadf, ath_protid2annotation,
            propagate_annotation.value, nonparasitic, hemiparasites, holoparasites
        )

        z = heatmap_df
        text = label_df
        customdata = anno_df
        n_rows, n_cols = heatmap_df.shape
        height = max(400, row_height * n_rows)

        shapes = []
        for i in range(1, n_cols):
            shapes.append(dict(type="line", x0=i-0.5, x1=i-0.5, y0=-0.5, y1=n_rows-0.5, line=dict(color="white", width=1)))
        for j in range(1, n_rows):
            shapes.append(dict(type="line", x0=-0.5, x1=n_cols-0.5, y0=j-0.5, y1=j-0.5, line=dict(color="white", width=1)))

        # in-place update (single re-render due to batch_update)
        with fig_w.batch_update():
            fig_w.data[0].z = z
            fig_w.data[0].x = xlabels
            fig_w.data[0].y = ylabels
            fig_w.data[0].text = text
            fig_w.data[0].customdata = customdata
            fig_w.layout.height = height
            fig_w.layout.shapes = shapes

        status.value = ""  # clear status
    except Exception:
        status.value = f"<pre>{traceback.format_exc()}</pre>"

# --- wire up observers ---
core_factor.observe(update_plot, names="value")
loss_factor.observe(update_plot, names="value")
propagate_annotation.observe(update_plot, names="value")
# Out:
# VBox(children=(HBox(children=(FloatSlider(value=0.9, continuous_update=False, description='Core factor:', max=…
# HTML(value='')
# /home/felixl/mambaforge/envs/DA/lib/python3.11/site-packages/jupyter_client/session.py:721: UserWarning:
#
# Message serialization failed with:
# Out of range float values are not JSON compliant
# Supporting this message is deprecated in jupyter-client 7, please make sure your message is JSON-compliant
# FigureWidget({
#     'data': [{'colorscale': [[0.0, '#00224e'], [0.1111111111111111, '#123570'],
#                              [0.2222222222222222, '#3b496c'], [0.3333333333333333,
#                              '#575d6d'], [0.4444444444444444, '#707173'],
#                              [0.5555555555555556, '#8a8678'], [0.6666666666666666,
#                              '#a59c74'], [0.7777777777777778, '#c3b369'],
#                              [0.8888888888888888, '#e1cc55'], [1.0, '#fee838']],
#               'customdata': array([['Ath: ammonium transporter 1;2', 'Ath: ammonium transporter 1;2',
#                                     'Ath: ammonium transporter 1;2', ..., 'Ath: ammonium transporter 1;2',
#                                     'Ath: ammonium transporter 1;2', 'Ath: ammonium transporter 1;2'],
#                                    ['Ath: NAC (No Apical Meristem) domain transcriptional regulator superfamily protein',
#                                     'Ath: NAC (No Apical Meristem) domain transcriptional regulator superfamily protein',
#                                     'Ath: NAC (No Apical Meristem) domain transcriptional regulator superfamily protein',
#                                     ...,
#                                     'Ath: NAC (No Apical Meristem) domain transcriptional regulator superfamily protein',
#                                     'Ath: NAC (No Apical Meristem) domain transcriptional regulator superfamily protein',
#                                     'Ath: NAC (No Apical Meristem) domain transcriptional regulator superfamily protein'],
#                                    ['Ath: UDP-Glycosyltransferase superfamily protein',
#                                     'Ath: UDP-Glycosyltransferase superfamily protein',
#                                     'Ath: UDP-Glycosyltransferase superfamily protein', ...,
#                                     'Ath: UDP-Glycosyltransferase superfamily protein',
#                                     'Ath: UDP-Glycosyltransferase superfamily protein',
#                                     'Ath: UDP-Glycosyltransferase superfamily protein'],
#                                    ...,
#                                    ['Ath: FTSH protease 6', 'Ath: FTSH protease 6',
#                                     'Ath: FTSH protease 6', ..., 'Ath: FTSH protease 6',
#                                     'Ath: FTSH protease 6', 'Ath: FTSH protease 6'],
#                                    ['Ath: tonoplast intrinsic protein 2;3',
#                                     'Ath: tonoplast intrinsic protein 2;3',
#                                     'Ath: tonoplast intrinsic protein 2;3', ...,
#                                     'Ath: tonoplast intrinsic protein 2;3',
#                                     'Ath: tonoplast intrinsic protein 2;3',
#                                     'Ath: tonoplast intrinsic protein 2;3'],
#                                    ['Ath: NAD(P)-binding Rossmann-fold superfamily protein',
#                                     'Ath: NAD(P)-binding Rossmann-fold superfamily protein',
#                                     'Ath: NAD(P)-binding Rossmann-fold superfamily protein', ...,
#                                     'Ath: NAD(P)-binding Rossmann-fold superfamily protein',
#                                     'Ath: NAD(P)-binding Rossmann-fold superfamily protein',
#                                     'Ath: NAD(P)-binding Rossmann-fold superfamily protein']], dtype=object),
#               'hoverinfo': 'x+text',
#               'hoverongaps': False,
#               'hovertemplate': '<b>%{x}</b><br>%{customdata}<br>%{text}<br><br><extra></extra>',
#               'showscale': False,
#               'text': array([['XP_059592558.1', 'XP_008350942.3', 'XP_024954204.2', ..., '*', '*',
#                               'CAA0829575.1'],
#                              ['XP_002271458.1', 'XP_070677283.1,XP_008383028.1', 'XP_015385606.2',
#                               ..., '*', 'GWHPBHPU017150', 'CAA0832512.1'],
#                              ['XP_002266304.1', 'XP_008378366.4,XP_028953596.2', 'XP_006481442.1',
#                               ..., '*', '*', 'CAA0836988.1'],
#                              ...,
#                              ['XP_002283393.2', 'XP_028963645.1', 'XP_006482602.1', ..., '*', '*',
#                               '*'],
#                              ['XP_002277904.3', 'XP_008373770.1', 'XP_006477173.2', ..., '*', '*',
#                               '*'],
#                              ['XP_002282638.2', '*', 'XP_006488388.2', ..., '*', '*', '*']],
#                             dtype=object),
#               'type': 'heatmap',
#               'uid': '10c34993-6e21-4776-9ef4-94fd4c7dbdeb',
#               'x': [Vitis vinifera, Malus domestica, Citrus sinensis, Arabidopsis
#                     thaliana, Solanum lycopersicum, Daucus carota, Rhododendron
#                     vialii, Cucumis sativus, Lactuca sativa, Beta vulgaris, Salvia
#                     miltiorrhiza, Coffea arabica, Eucalyptus grandis, Vigna
#                     angularis, Populus nigra, Gossypium raimondii, Tripterygium
#                     wilfordii, Alnus glutinosa, Pedicularis kansuensis, Santalum
#                     album_tanxiang, Castilleja foliolosa, Phtheirospermum
#                     japonicum, Malania oleifera, Cuscuta europaea, Balanophora
#                     subcupularis, Orobanche cernua_cumana, Phelipanche aegyptiaca,
#                     Striga hermonthica],
#               'y': [OG32, OG35, OG38, ..., OG14178, OG14267, OG14347],
#               'z': array([[0.0, 0.0, 0.0, ..., None, None, 1],
#                           [0.0, 0.0, 0.0, ..., None, 1, 1],
#                           [0.0, 0.0, 0.0, ..., None, None, 1],
#                           ...,
#                           [0.0, 0.0, 0.0, ..., None, None, None],
#                           [0.0, 0.0, 0.0, ..., None, None, None],
#                           [0.0, nan, 0.0, ..., None, None, None]], dtype=object)}],
#     'layout': {'height': 5000,
#                'shapes': [{'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': 0.5,
#                            'x1': 0.5,
#                            'y0': -0.5,
#                            'y1': 249.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': 1.5,
#                            'x1': 1.5,
#                            'y0': -0.5,
#                            'y1': 249.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': 2.5,
#                            'x1': 2.5,
#                            'y0': -0.5,
#                            'y1': 249.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': 3.5,
#                            'x1': 3.5,
#                            'y0': -0.5,
#                            'y1': 249.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': 4.5,
#                            'x1': 4.5,
#                            'y0': -0.5,
#                            'y1': 249.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': 5.5,
#                            'x1': 5.5,
#                            'y0': -0.5,
#                            'y1': 249.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': 6.5,
#                            'x1': 6.5,
#                            'y0': -0.5,
#                            'y1': 249.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': 7.5,
#                            'x1': 7.5,
#                            'y0': -0.5,
#                            'y1': 249.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': 8.5,
#                            'x1': 8.5,
#                            'y0': -0.5,
#                            'y1': 249.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': 9.5,
#                            'x1': 9.5,
#                            'y0': -0.5,
#                            'y1': 249.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': 10.5,
#                            'x1': 10.5,
#                            'y0': -0.5,
#                            'y1': 249.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': 11.5,
#                            'x1': 11.5,
#                            'y0': -0.5,
#                            'y1': 249.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': 12.5,
#                            'x1': 12.5,
#                            'y0': -0.5,
#                            'y1': 249.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': 13.5,
#                            'x1': 13.5,
#                            'y0': -0.5,
#                            'y1': 249.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': 14.5,
#                            'x1': 14.5,
#                            'y0': -0.5,
#                            'y1': 249.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': 15.5,
#                            'x1': 15.5,
#                            'y0': -0.5,
#                            'y1': 249.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': 16.5,
#                            'x1': 16.5,
#                            'y0': -0.5,
#                            'y1': 249.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': 17.5,
#                            'x1': 17.5,
#                            'y0': -0.5,
#                            'y1': 249.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': 18.5,
#                            'x1': 18.5,
#                            'y0': -0.5,
#                            'y1': 249.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': 19.5,
#                            'x1': 19.5,
#                            'y0': -0.5,
#                            'y1': 249.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': 20.5,
#                            'x1': 20.5,
#                            'y0': -0.5,
#                            'y1': 249.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': 21.5,
#                            'x1': 21.5,
#                            'y0': -0.5,
#                            'y1': 249.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': 22.5,
#                            'x1': 22.5,
#                            'y0': -0.5,
#                            'y1': 249.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': 23.5,
#                            'x1': 23.5,
#                            'y0': -0.5,
#                            'y1': 249.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': 24.5,
#                            'x1': 24.5,
#                            'y0': -0.5,
#                            'y1': 249.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': 25.5,
#                            'x1': 25.5,
#                            'y0': -0.5,
#                            'y1': 249.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': 26.5,
#                            'x1': 26.5,
#                            'y0': -0.5,
#                            'y1': 249.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 0.5,
#                            'y1': 0.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 1.5,
#                            'y1': 1.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 2.5,
#                            'y1': 2.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 3.5,
#                            'y1': 3.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 4.5,
#                            'y1': 4.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 5.5,
#                            'y1': 5.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 6.5,
#                            'y1': 6.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 7.5,
#                            'y1': 7.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 8.5,
#                            'y1': 8.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 9.5,
#                            'y1': 9.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 10.5,
#                            'y1': 10.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 11.5,
#                            'y1': 11.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 12.5,
#                            'y1': 12.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 13.5,
#                            'y1': 13.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 14.5,
#                            'y1': 14.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 15.5,
#                            'y1': 15.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 16.5,
#                            'y1': 16.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 17.5,
#                            'y1': 17.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 18.5,
#                            'y1': 18.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 19.5,
#                            'y1': 19.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 20.5,
#                            'y1': 20.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 21.5,
#                            'y1': 21.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 22.5,
#                            'y1': 22.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 23.5,
#                            'y1': 23.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 24.5,
#                            'y1': 24.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 25.5,
#                            'y1': 25.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 26.5,
#                            'y1': 26.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 27.5,
#                            'y1': 27.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 28.5,
#                            'y1': 28.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 29.5,
#                            'y1': 29.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 30.5,
#                            'y1': 30.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 31.5,
#                            'y1': 31.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 32.5,
#                            'y1': 32.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 33.5,
#                            'y1': 33.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 34.5,
#                            'y1': 34.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 35.5,
#                            'y1': 35.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 36.5,
#                            'y1': 36.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 37.5,
#                            'y1': 37.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 38.5,
#                            'y1': 38.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 39.5,
#                            'y1': 39.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 40.5,
#                            'y1': 40.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 41.5,
#                            'y1': 41.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 42.5,
#                            'y1': 42.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 43.5,
#                            'y1': 43.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 44.5,
#                            'y1': 44.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 45.5,
#                            'y1': 45.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 46.5,
#                            'y1': 46.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 47.5,
#                            'y1': 47.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 48.5,
#                            'y1': 48.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 49.5,
#                            'y1': 49.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 50.5,
#                            'y1': 50.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 51.5,
#                            'y1': 51.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 52.5,
#                            'y1': 52.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 53.5,
#                            'y1': 53.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 54.5,
#                            'y1': 54.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 55.5,
#                            'y1': 55.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 56.5,
#                            'y1': 56.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 57.5,
#                            'y1': 57.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 58.5,
#                            'y1': 58.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 59.5,
#                            'y1': 59.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 60.5,
#                            'y1': 60.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 61.5,
#                            'y1': 61.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 62.5,
#                            'y1': 62.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 63.5,
#                            'y1': 63.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 64.5,
#                            'y1': 64.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 65.5,
#                            'y1': 65.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 66.5,
#                            'y1': 66.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 67.5,
#                            'y1': 67.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 68.5,
#                            'y1': 68.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 69.5,
#                            'y1': 69.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 70.5,
#                            'y1': 70.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 71.5,
#                            'y1': 71.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 72.5,
#                            'y1': 72.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 73.5,
#                            'y1': 73.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 74.5,
#                            'y1': 74.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 75.5,
#                            'y1': 75.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 76.5,
#                            'y1': 76.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 77.5,
#                            'y1': 77.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 78.5,
#                            'y1': 78.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 79.5,
#                            'y1': 79.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 80.5,
#                            'y1': 80.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 81.5,
#                            'y1': 81.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 82.5,
#                            'y1': 82.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 83.5,
#                            'y1': 83.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 84.5,
#                            'y1': 84.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 85.5,
#                            'y1': 85.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 86.5,
#                            'y1': 86.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 87.5,
#                            'y1': 87.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 88.5,
#                            'y1': 88.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 89.5,
#                            'y1': 89.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 90.5,
#                            'y1': 90.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 91.5,
#                            'y1': 91.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 92.5,
#                            'y1': 92.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 93.5,
#                            'y1': 93.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 94.5,
#                            'y1': 94.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 95.5,
#                            'y1': 95.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 96.5,
#                            'y1': 96.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 97.5,
#                            'y1': 97.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 98.5,
#                            'y1': 98.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 99.5,
#                            'y1': 99.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 100.5,
#                            'y1': 100.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 101.5,
#                            'y1': 101.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 102.5,
#                            'y1': 102.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 103.5,
#                            'y1': 103.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 104.5,
#                            'y1': 104.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 105.5,
#                            'y1': 105.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 106.5,
#                            'y1': 106.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 107.5,
#                            'y1': 107.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 108.5,
#                            'y1': 108.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 109.5,
#                            'y1': 109.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 110.5,
#                            'y1': 110.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 111.5,
#                            'y1': 111.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 112.5,
#                            'y1': 112.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 113.5,
#                            'y1': 113.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 114.5,
#                            'y1': 114.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 115.5,
#                            'y1': 115.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 116.5,
#                            'y1': 116.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 117.5,
#                            'y1': 117.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 118.5,
#                            'y1': 118.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 119.5,
#                            'y1': 119.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 120.5,
#                            'y1': 120.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 121.5,
#                            'y1': 121.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 122.5,
#                            'y1': 122.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 123.5,
#                            'y1': 123.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 124.5,
#                            'y1': 124.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 125.5,
#                            'y1': 125.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 126.5,
#                            'y1': 126.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 127.5,
#                            'y1': 127.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
# ...
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 190.5,
#                            'y1': 190.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 191.5,
#                            'y1': 191.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 192.5,
#                            'y1': 192.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 193.5,
#                            'y1': 193.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 194.5,
#                            'y1': 194.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 195.5,
#                            'y1': 195.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 196.5,
#                            'y1': 196.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 197.5,
#                            'y1': 197.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 198.5,
#                            'y1': 198.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 199.5,
#                            'y1': 199.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 200.5,
#                            'y1': 200.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 201.5,
#                            'y1': 201.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 202.5,
#                            'y1': 202.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 203.5,
#                            'y1': 203.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 204.5,
#                            'y1': 204.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 205.5,
#                            'y1': 205.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 206.5,
#                            'y1': 206.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 207.5,
#                            'y1': 207.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 208.5,
#                            'y1': 208.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 209.5,
#                            'y1': 209.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 210.5,
#                            'y1': 210.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 211.5,
#                            'y1': 211.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 212.5,
#                            'y1': 212.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 213.5,
#                            'y1': 213.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 214.5,
#                            'y1': 214.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 215.5,
#                            'y1': 215.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 216.5,
#                            'y1': 216.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 217.5,
#                            'y1': 217.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 218.5,
#                            'y1': 218.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 219.5,
#                            'y1': 219.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 220.5,
#                            'y1': 220.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 221.5,
#                            'y1': 221.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 222.5,
#                            'y1': 222.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 223.5,
#                            'y1': 223.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 224.5,
#                            'y1': 224.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 225.5,
#                            'y1': 225.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 226.5,
#                            'y1': 226.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 227.5,
#                            'y1': 227.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 228.5,
#                            'y1': 228.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 229.5,
#                            'y1': 229.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 230.5,
#                            'y1': 230.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 231.5,
#                            'y1': 231.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 232.5,
#                            'y1': 232.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 233.5,
#                            'y1': 233.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 234.5,
#                            'y1': 234.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 235.5,
#                            'y1': 235.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 236.5,
#                            'y1': 236.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 237.5,
#                            'y1': 237.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 238.5,
#                            'y1': 238.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 239.5,
#                            'y1': 239.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 240.5,
#                            'y1': 240.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 241.5,
#                            'y1': 241.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 242.5,
#                            'y1': 242.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 243.5,
#                            'y1': 243.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 244.5,
#                            'y1': 244.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 245.5,
#                            'y1': 245.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 246.5,
#                            'y1': 246.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 247.5,
#                            'y1': 247.5},
#                           {'line': {'color': 'white', 'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': 27.5,
#                            'y0': 248.5,
#                            'y1': 248.5}],
#                'template': '...',
#                'width': 800,
#                'xaxis': {'showgrid': False},
#                'yaxis': {'autorange': 'reversed', 'showgrid': False}}
# })
